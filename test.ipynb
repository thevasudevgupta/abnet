# %%
import torch
t = torch.ones(2, 3).long()

# %%
from data_utils import DataLoader, Tokenizer
from training import wmt16_ro_en, iwslt14_de_en

t = Tokenizer("bert-base-german-cased", "bert-base-uncased")
dl = DataLoader(iwslt14_de_en, t)

# %%
tr, vsl, tst = dl()
# Out:
# total size of tr data (src, tgt) :  (160239, 160239)
# total size of val data (src, tgt) :  (7283, 7283)
# total size of tst data (src, tgt) :  (6750, 6750)

# %%
# tokenizer tested completely
# dataloader tested completely
# model saving loading working properly
#

# %%
# TODO should we query over seqlen

# TODO
# remember lengths embedding must be shuch that its max value is max val of tgt seqlen


# TODO define loss function
#

# %%
from modeling import TransformerMaskPredict, Dict
import yaml

config = yaml.safe_load(open("transformer_config/iwslt14_de_en.yaml", "r"))
config = Dict.from_nested_dict(config)
model = TransformerMaskPredict(config)
model.eval()
# Out:
# Some weights of the model checkpoint at bert-base-german-cased were not used when initializing BertModel: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertModel were not initialized from the model checkpoint at bert-base-german-cased and are newly initialized: ['bert.embeddings.position_ids', 'bert.embeddings.length_embedding.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
